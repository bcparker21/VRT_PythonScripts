# %%
import gtfstk as gt
import pandas as pd
import geopandas as gpd
import numpy as np
import tkinter as tk
import requests, zipfile, io, os
from tkinter import filedialog

# %%
zip_file_url=r"http://valleyregionaltransit.org/gtfs/VRT_Transit1.zip"
r = requests.get(zip_file_url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall("gtfs")
gtfs_filename=os.path.basename(zip_file_url)
gtfs_filename=os.path.splitext(gtfs_filename)[0]
feed=gt.read_gtfs("gtfs",dist_units='mi')

# %%
route_names=feed.routes['route_short_name']
route_namesArray=route_names.unique()
route_names={i:route_namesArray[i] for i in range(len(route_names.unique()))}
route_names.update([((len(route_names)+1),'All')])
route_names=route_names.values()

# %%
def button_gtfs_clicked():
    root.gtfs=filedialog.askopenfilename(initialdir="/",title="Select GTFS Zip file",filetypes = (("zip files","*.zip"),("all files","*.*")))
def button_mbsl_clicked():
    root.mbsl=filedialog.askopenfilename(initialdir=r"N:\Planning - New File Structure\MASTER BUS STOP LIST",title="Select Master Bus Stop List")
def button_outfolder_clicked():
    root.outfolder=filedialog.askdirectory(initialdir="/",title="Select Output folder")
def close_window():
    root.route=tkvar.get()
    root.destroy()

root=tk.Tk()
root.title('Stops Changes')

tkvar=tk.StringVar(root)
tkvar.set("All")

label_gtfs=tk.Label(root,text="Select GTFS zip file.")
label_gtfs.grid(column=0,row=0)
button_gtfs=tk.Button(root,text="Browse",command=button_gtfs_clicked)
button_gtfs.grid(column=0,row=1)

label_mbsl=tk.Label(root,text="Select Master Bus Stop List.")
label_mbsl.grid(column=0,row=2)
button_mbsl=tk.Button(root,text="Browse",command=button_mbsl_clicked)
button_mbsl.grid(column=0,row=3)

label_out=tk.Label(root,text="Select an output folder")
label_out.grid(column=0,row=4)
button_out=tk.Button(root,text="Browse",command=button_outfolder_clicked)
button_out.grid(column=0,row=5)

route_label=tk.Label(root,text="Pick a Route")
route_label.grid(column=0,row=6)
route_choice=tk.OptionMenu(root,tkvar,*route_names)
route_choice.grid(column=0,row=7)

button_run=tk.Button(root,text='Run',width=25,command=close_window)
button_run.grid(column=0,row=8)
root.mainloop()

# %%
root.gtfs
# Out:
# 'N:/Planning - New File Structure/GIS/Data/OFFICIAL CURRENT/GTFS/VRT_Transit1.zip'

# %%
root.mbsl
# Out:
# 'N:/Planning - New File Structure/MASTER BUS STOP LIST/20190604 Master Bus Stop List.xlsx'

# %%
root.outfolder
# Out:
# 'N:/Planning - New File Structure/GIS/Data/BrochureData/test/StopLists'

# %%
feed=gt.read_gtfs(root.gtfs,dist_units='mi')
MBSL=pd.read_excel(root.mbsl,sheet_name='Master Amenities List',skiprows=2,dtype={'Stop Id':str},na_values=False)
MBSL=MBSL[['Stop Id','Ada Accessible','Shelter']].fillna(0)
gtfs_filename=os.path.basename(root.gtfs)
gtfs_filename=os.path.splitext(gtfs_filename)[0]

# %%
def getRouteStops(route_short_name):
    df=feed.stop_times.merge(feed.trips).merge(feed.routes).merge(feed.stops)
    df=df.loc[df['route_short_name']==route_short_name]
    df=df.groupby(['stop_id','direction_id'],as_index=False).first()
    return df

# %%
def getDuplicateColumns(df):
    duplicateColumnNames = set()
    # Iterate over all the columns in dataframe
    for x in range(df.shape[1]):
        # Select column at xth index.
        col = df.iloc[:, x]
        # Iterate over all the columns in DataFrame from (x+1)th index till end
        for y in range(x + 1, df.shape[1]):
            # Select column at yth index.
            otherCol = df.iloc[:, y]
            # Check if two columns at x 7 y index are equal
            if col.equals(otherCol):
                duplicateColumnNames.add(df.columns.values[y])
 
    return list(duplicateColumnNames)

# %%
def getUniquePatterns(route_short_name):
    df=feed.stop_times.merge(feed.trips).merge(feed.routes)
    route=df.loc[df['route_short_name']==route_short_name]
    route=route.pivot(index='stop_sequence',columns='trip_id',values='stop_id')
    route=route.drop(getDuplicateColumns(route),axis=1)
    alpha=[]
    for letter in range(65,(65+len(route.columns))):
        alpha.append(chr(letter))
    route.columns=alpha
    route=pd.DataFrame(route.unstack()).reset_index()
    route.rename({'level_0':'Pattern'},axis=1,inplace=True)
    return route
getUniquePatterns('4')
# Out:
#    Pattern  stop_sequence         0
# 0        A              0  01010188
# 1        A              1  01011025
# 2        A              2  01010186
# 3        A              3  01010672
# 4        A              4  01010674
# 5        A              5  01010676
# 6        A              6  01010679
# 7        A              7  01010680
# 8        A              8  01010683
# 9        A              9  01010522
# 10       A             10  01010684
# 11       A             11  01010686
# 12       A             12  01010688
# 13       A             13  01010690
# 14       A             14  01010691
# 15       A             15  01010693
# 16       A             16  01010695
# 17       A             17  01010697
# 18       A             18  01010699
# 19       A             19   1011037
# 20       A             20  01010702
# 21       A             21  01010703
# 22       A             22  01010705
# 23       A             23  01010707
# 24       A             24  01010710
# 25       A             25  01010670
# 26       A             26  01019999
# 27       B              0  01019999
# 28       B              1  01010711
# 29       B              2  01010709
# 30       B              3  01010706
# 31       B              4  01010704
# 32       B              5  01010701
# 33       B              6  01010700
# 34       B              7  01010698
# 35       B              8  01010696
# 36       B              9  01010694
# 37       B             10  01010692
# 38       B             11  01010689
# 39       B             12  01010687
# 40       B             13  01010685
# 41       B             14  01010534
# 42       B             15  01010682
# 43       B             16  01010681
# 44       B             17  01010678
# 45       B             18  01010677
# 46       B             19  01010675
# 47       B             20  01010673
# 48       B             21  01010671
# 49       B             22  01010184
# 50       B             23  01010930
# 51       B             24  01010187
# 52       B             25  01010188
# 53       B             26       NaN

# %%
def timepointer(route_short_name):
    route=feed.stop_times.merge(feed.trips).merge(feed.routes).merge(feed.stops)
    route=route.loc[route['route_short_name']==route_short_name]
    route=route.groupby(['direction_id','shape_id','stop_sequence'],as_index=False).first()
    route=route.loc[route['departure_time'].notna()]
    route=route[['stop_name','shape_id','direction_id','stop_sequence','departure_time','stop_id']]
    route['stop_label']=route['stop_name']
    route['stop_label'].replace(r"[NSEW][NSEW][CM]","",regex=True,inplace=True)
    firsts=pd.DataFrame(route.loc[~route['stop_label'].duplicated()][['stop_label','stop_sequence','direction_id','stop_id']]).reset_index()
    firsts['number']=firsts.index+1
    dups=pd.DataFrame(route.loc[route['stop_label'].duplicated()][['stop_label','stop_sequence','direction_id','stop_id']]).reset_index()
    dups2=dups.merge(firsts,on='stop_label')
    dups2=dups2[['stop_label','number']]
    dups2[['direction_id','stop_sequence','stop_id']]=dups[['direction_id','stop_sequence','stop_id']]
    df2=firsts.append(dups2)
    df2=df2.groupby(['stop_id','direction_id'],as_index=False).first()
    df2.sort_values(['direction_id','stop_sequence'],inplace=True)
    df2=df2[['stop_id','stop_label','number']]
    return df2

# %%
def otherRoutes(route_short_name):
    df=feed.stop_times.merge(feed.trips)
    df=df.merge(feed.routes)
    route=df.loc[df['route_short_name']==route_short_name]
    route=route.groupby('stop_id',as_index=False).first()
    df=df.loc[df['route_short_name']!=route_short_name]
    df=df.groupby(['stop_id','route_short_name'],as_index=False).first()
    df=pd.DataFrame(df.groupby('stop_id')['route_short_name'].agg(lambda x: ', '.join(x))).reset_index()
    df=df[['stop_id','route_short_name']]
    df=df.rename({'route_short_name':'other_routes'},axis=1)
    route=route.merge(df,how='left')
    route=route[['stop_id','other_routes']]
    return route

# %%
def MergeMBSL(route_short_name):
    df=getRouteStops(route_short_name)
    df=df.merge(MBSL,left_on='stop_id',right_on='Stop Id')
    df=df[['stop_id','Ada Accessible','Shelter']]
    return df

# %%
def stopLister(route_short_name, save_folder=None):
    df=getUniquePatterns(route_short_name)
    df=df.merge(getRouteStops(route_short_name),how='left')
    df=df.merge(timepointer(route_short_name),how='left')
    df=df.merge(otherRoutes(route_short_name),how='left')
    df=df.merge(MergeMBSL(route_short_name),how='left')
    df=df.groupby(['pattern','stop_id'],as_index=False).first()
    df.sort_values(['pattern','direction_id','stop_sequence'],inplace=True)
#     df=df[['pattern','route_short_name','route_long_name','direction_id','stop_sequence','stop_id','number','stop_name','Ada Accessible','Shelter','other_routes']]
    df.rename({'number':'Timepoint','stop_name':'Stop Name','Ada Accessible':'Accessible','other_routes':'Other Routes'},axis=1,inplace=True)
    if save_folder:
        df.to_excel(save_folder+r"\{}_stopList.xlsx".format(route_short_name))
    return df
stopLister('40')
# Out:
#    pattern   stop_id  direction_id                 trip_id arrival_time  \
# 12       A  14010090           0.0  40_06:00_Weekday_83413     06:00:00
# 14       A  14050080           0.0  40_06:00_Weekday_83413          NaN
# 15       A  14050089           0.0  40_06:00_Weekday_83413          NaN
# 16       A  14050100           0.0  40_06:00_Weekday_83413          NaN
# 13       A  14050009           0.0  40_06:00_Weekday_83413          NaN
# 17       A  14050891           0.0  40_06:00_Weekday_83413     06:25:00
# 18       A  14050901           0.0  40_06:00_Weekday_83413          NaN
# 11       A  01050264           0.0  40_06:00_Weekday_83413          NaN
# 10       A  01050084           0.0  40_06:00_Weekday_83413     06:44:00
# 7        A  01010632           0.0  40_06:00_Weekday_83413          NaN
# 2        A  01010120           0.0  40_06:00_Weekday_83413     07:09:00
# 1        A  01010119           0.0  40_06:00_Weekday_83413          NaN
# 0        A  01010117           0.0  40_06:00_Weekday_83413     07:12:00
# 5        A  01010163           0.0  40_06:00_Weekday_83413          NaN
# 4        A  01010161           0.0  40_06:00_Weekday_83413          NaN
# 6        A  01010497           0.0  40_06:00_Weekday_83413          NaN
# 8        A  01010637           0.0  40_06:00_Weekday_83413          NaN
# 9        A  01010905           0.0  40_06:00_Weekday_83413          NaN
# 3        A  01010143           0.0  40_06:00_Weekday_83413     07:25:00
# 25       B  14010090           0.0  40_06:00_Weekday_83413     06:00:00
# 26       B  14050009           0.0  40_06:00_Weekday_83413          NaN
# 30       B  14050891           0.0  40_06:00_Weekday_83413     06:25:00
# 21       B  01010143           0.0  40_06:00_Weekday_83413     07:25:00
# 19       B  01010106           1.0  40_08:25_Weekday_83409          NaN
# 20       B  01010107           1.0  40_08:25_Weekday_83409          NaN
# 22       B  01010168           1.0  40_08:25_Weekday_83409     08:30:00
# 23       B  01050083           1.0  40_08:25_Weekday_83409     08:46:00
# 24       B  01050263           1.0  40_08:25_Weekday_83409          NaN
# 31       B  14050902           1.0  40_08:25_Weekday_83409          NaN
# 29       B  14050104           1.0  40_08:25_Weekday_83409          NaN
# ..     ...       ...           ...                     ...          ...
# 52       D  01050083           1.0  40_08:25_Weekday_83409     08:46:00
# 44       D  01010111           1.0  40_15:51_Weekday_83417          NaN
# 53       D  01050263           1.0  40_08:25_Weekday_83409          NaN
# 51       D  01010870           1.0  40_15:51_Weekday_83417     16:00:00
# 56       D  14050902           1.0  40_08:25_Weekday_83409          NaN
# 50       D  01010619           1.0  40_15:51_Weekday_83417          NaN
# 67       E  14010090           0.0  40_06:00_Weekday_83413     06:00:00
# 68       E  14050009           0.0  40_06:00_Weekday_83413          NaN
# 72       E  14050891           0.0  40_06:00_Weekday_83413     06:25:00
# 59       E  01010157           0.0  40_14:45_Weekday_83418     15:51:00
# 60       E  01010158           1.0  40_15:51_Weekday_83417          NaN
# 62       E  01010498           1.0  40_15:51_Weekday_83417          NaN
# 61       E  01010164           1.0  40_15:51_Weekday_83417          NaN
# 58       E  01010113           1.0  40_15:51_Weekday_83417     15:57:00
# 65       E  01050083           1.0  40_08:25_Weekday_83409     08:46:00
# 57       E  01010111           1.0  40_15:51_Weekday_83417          NaN
# 66       E  01050263           1.0  40_08:25_Weekday_83409          NaN
# 64       E  01010870           1.0  40_15:51_Weekday_83417     16:00:00
# 73       E  14050902           1.0  40_08:25_Weekday_83409          NaN
# 63       E  01010619           1.0  40_15:51_Weekday_83417          NaN
# 71       E  14050104           1.0  40_08:25_Weekday_83409          NaN
# 70       E  14050090           1.0  40_08:25_Weekday_83409          NaN
# 69       E  14050081           1.0  40_08:25_Weekday_83409          NaN
# 79       F  14050891           0.0  40_06:00_Weekday_83413     06:25:00
# 80       F  14050901           0.0  40_06:00_Weekday_83413          NaN
# 78       F  01050264           0.0  40_06:00_Weekday_83413          NaN
# 77       F  01050084           0.0  40_06:00_Weekday_83413     06:44:00
# 74       F  01010126           0.0  40_14:45_Weekday_83418          NaN
# 75       F  01010154           0.0  40_14:45_Weekday_83418          NaN
# 76       F  01010157           0.0  40_14:45_Weekday_83418     15:51:00
#
#    departure_time  stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 12       06:00:00            0.0            NaN          NaN            NaN
# 14            NaN            1.0            NaN          NaN            NaN
# 15            NaN            2.0            NaN          NaN            NaN
# 16            NaN            3.0            NaN          NaN            NaN
# 13            NaN            4.0            NaN          NaN            NaN
# 17       06:25:00            5.0            NaN          NaN            NaN
# 18            NaN            6.0            NaN          NaN            NaN
# 11            NaN            7.0            NaN          NaN            NaN
# 10       06:44:00            8.0            NaN          NaN            NaN
# 7             NaN            9.0            NaN          NaN            NaN
# 2        07:09:00           10.0            NaN          NaN            NaN
# 1             NaN           11.0            NaN          NaN            NaN
# 0        07:12:00           12.0            NaN          NaN            NaN
# 5             NaN           13.0            NaN          NaN            NaN
# 4             NaN           14.0            NaN          NaN            NaN
# 6             NaN           15.0            NaN          NaN            NaN
# 8             NaN           16.0            NaN          NaN            NaN
# 9             NaN           17.0            NaN          NaN            NaN
# 3        07:25:00           18.0            NaN          NaN            NaN
# 25       06:00:00            0.0            NaN          NaN            NaN
# 26            NaN            4.0            NaN          NaN            NaN
# 30       06:25:00            5.0            NaN          NaN            NaN
# 21       07:25:00           18.0            NaN          NaN            NaN
# 19            NaN            1.0            NaN          NaN            NaN
# 20            NaN            2.0            NaN          NaN            NaN
# 22       08:30:00            3.0            NaN          NaN            NaN
# 23       08:46:00            4.0            NaN          NaN            NaN
# 24            NaN            5.0            NaN          NaN            NaN
# 31            NaN            6.0            NaN          NaN            NaN
# 29            NaN            9.0            NaN          NaN            NaN
# ..            ...            ...            ...          ...            ...
# 52       08:46:00            4.0            NaN          NaN            NaN
# 44            NaN            5.0            NaN          NaN            NaN
# 53            NaN            5.0            NaN          NaN            NaN
# 51       16:00:00            6.0            NaN          NaN            NaN
# 56            NaN            6.0            NaN          NaN            NaN
# 50            NaN            7.0            NaN          NaN            NaN
# 67       06:00:00            0.0            NaN          NaN            NaN
# 68            NaN            4.0            NaN          NaN            NaN
# 72       06:25:00            5.0            NaN          NaN            NaN
# 59       15:51:00           11.0            NaN          NaN            NaN
# 60            NaN            1.0            NaN          NaN            NaN
# 62            NaN            2.0            NaN          NaN            NaN
# 61            NaN            3.0            NaN          NaN            NaN
# 58       15:57:00            4.0            NaN          NaN            NaN
# 65       08:46:00            4.0            NaN          NaN            NaN
# 57            NaN            5.0            NaN          NaN            NaN
# 66            NaN            5.0            NaN          NaN            NaN
# 64       16:00:00            6.0            NaN          NaN            NaN
# 73            NaN            6.0            NaN          NaN            NaN
# 63            NaN            7.0            NaN          NaN            NaN
# 71            NaN            9.0            NaN          NaN            NaN
# 70            NaN           10.0            NaN          NaN            NaN
# 69            NaN           11.0            NaN          NaN            NaN
# 79       06:25:00            5.0            NaN          NaN            NaN
# 80            NaN            6.0            NaN          NaN            NaN
# 78            NaN            7.0            NaN          NaN            NaN
# 77       06:44:00            8.0            NaN          NaN            NaN
# 74            NaN            9.0            NaN          NaN            NaN
# 75            NaN           10.0            NaN          NaN            NaN
# 76       15:51:00           11.0            NaN          NaN            NaN
#
#      ...                                Stop Name stop_desc   stop_lat  \
# 12   ...                 Happy Day Transit Center       NaN  43.627814
# 14   ...     Caldwell & Karcher Mall Entrance SWC       NaN  43.602790
# 15   ...                    Caldwell & Canyon SWC       NaN  43.588361
# 16   ...         Northside & 6th Street North SEC       NaN  43.597887
# 13   ...                          CWI Main Campus       NaN  43.615030
# 17   ...                                  CWI P&R       NaN  43.611333
# 18   ...                     Franklin & Tiegs SEC       NaN  43.604930
# 11   ...                  Overland & Ten Mile SEM       NaN  43.584860
# 10   ...              Overland & Black Marlin SEC       NaN  43.590000
# 7    ...                          13th & Main SEC       NaN  43.618453
# 2    ...                           Main & 8th SWC       NaN  43.615788
# 1    ...                           Main & 5th SWC       NaN  43.613845
# 0    ...                           Main & 1st SWC       NaN  43.611546
# 5    ...                      Broadway & Park NWC       NaN  43.606420
# 4    ...                Broadway & University NWC       NaN  43.601128
# 6    ...                      Beacon & Denver NEC       NaN  43.598482
# 8    ...                     Beacon & Manitou NEC       NaN  43.598510
# 9    ...      University @ BSU Transit Center NEC       NaN  43.601776
# 3    ...               University @ BSU Admin NWM       NaN  43.603233
# 25   ...                 Happy Day Transit Center       NaN  43.627814
# 26   ...                          CWI Main Campus       NaN  43.615030
# 30   ...                                  CWI P&R       NaN  43.611333
# 21   ...               University @ BSU Admin NWM       NaN  43.603233
# 19   ...               Capitol & Cesar Chavez SEM       NaN  43.607423
# 20   ...                      Capitol & River NEC       NaN  43.610543
# 22   ...                          Front & 9th NEC       NaN  43.614694
# 23   ...              Overland & Black Marlin NWC       NaN  43.590180
# 24   ...                  Overland & Ten Mile NEC       NaN  43.585033
# 31   ...                     Franklin & Tiegs NWC       NaN  43.605113
# 29   ...                      Northside & 6th NWC       NaN  43.598506
# ..   ...                                      ...       ...        ...
# 52   ...              Overland & Black Marlin NWC       NaN  43.590180
# 44   ...                          Idaho & 5th NEC       NaN  43.614607
# 53   ...                  Overland & Ten Mile NEC       NaN  43.585033
# 51   ...                          Idaho & 9th NWC       NaN  43.617158
# 56   ...                     Franklin & Tiegs NWC       NaN  43.605113
# 50   ...                         Idaho & 11th NWC       NaN  43.618434
# 67   ...                 Happy Day Transit Center       NaN  43.627814
# 68   ...                          CWI Main Campus       NaN  43.615030
# 72   ...                                  CWI P&R       NaN  43.611333
# 59   ...                   University & Joyce SEC       NaN  43.602699
# 60   ...                 Lincoln & University NWC       NaN  43.601055
# 62   ...                       Beacon & Grant SWC       NaN  43.598322
# 61   ...                      Broadway & Park NEM       NaN  43.607308
# 58   ...                          Idaho & 1st NEC       NaN  43.612245
# 65   ...              Overland & Black Marlin NWC       NaN  43.590180
# 57   ...                          Idaho & 5th NEC       NaN  43.614607
# 66   ...                  Overland & Ten Mile NEC       NaN  43.585033
# 64   ...                          Idaho & 9th NWC       NaN  43.617158
# 73   ...                     Franklin & Tiegs NWC       NaN  43.605113
# 63   ...                         Idaho & 11th NWC       NaN  43.618434
# 71   ...                      Northside & 6th NWC       NaN  43.598506
# 70   ...                    Caldwell & Canyon NEC       NaN  43.588295
# 69   ...           Caldwell @ D.L. Evans Bank NEM       NaN  43.603316
# 79   ...                                  CWI P&R       NaN  43.611333
# 80   ...                     Franklin & Tiegs SEC       NaN  43.604930
# 78   ...                  Overland & Ten Mile SEM       NaN  43.584860
# 77   ...              Overland & Black Marlin SEC       NaN  43.590000
# 74   ...                          9th & River SWC       NaN  43.610881
# 75   ...                   University & Earle SWC       NaN  43.604935
# 76   ...                   University & Joyce SEC       NaN  43.602699
#
#       stop_lon               zone_id                stop_label Timepoint  \
# 12 -116.634915  zoneforstop_VRT_3324  Happy Day Transit Center       1.0
# 14 -116.599244   zoneforstop_VRT_939                       NaN       NaN
# 15 -116.578188   zoneforstop_VRT_943                       NaN       NaN
# 16 -116.572842  zoneforstop_VRT_3170                       NaN       NaN
# 13 -116.507148   zoneforstop_VRT_351                       NaN       NaN
# 17 -116.508994  zoneforstop_VRT_3325                   CWI P&R       2.0
# 18 -116.509191  zoneforstop_VRT_4191                       NaN       NaN
# 11 -116.432335  zoneforstop_VRT_3180                       NaN       NaN
# 10 -116.397947  zoneforstop_VRT_2372  Overland & Black Marlin        3.0
# 7  -116.209337  zoneforstop_VRT_1208                       NaN       NaN
# 2  -116.204035   zoneforstop_VRT_787               Main & 8th        4.0
# 1  -116.200199  zoneforstop_VRT_3028                       NaN       NaN
# 0  -116.195666  zoneforstop_VRT_3030               Main & 1st        5.0
# 5  -116.193514  zoneforstop_VRT_2841                       NaN       NaN
# 4  -116.193657  zoneforstop_VRT_3211                       NaN       NaN
# 6  -116.194989  zoneforstop_VRT_2813                       NaN       NaN
# 8  -116.198397   zoneforstop_VRT_212                       NaN       NaN
# 9  -116.202237  zoneforstop_VRT_2814                       NaN       NaN
# 3  -116.205126  zoneforstop_VRT_2816   University @ BSU Admin        6.0
# 25 -116.634915  zoneforstop_VRT_3324  Happy Day Transit Center       1.0
# 26 -116.507148   zoneforstop_VRT_351                       NaN       NaN
# 30 -116.508994  zoneforstop_VRT_3325                   CWI P&R       2.0
# 21 -116.205126  zoneforstop_VRT_2816   University @ BSU Admin        6.0
# 19 -116.209372   zoneforstop_VRT_217                       NaN       NaN
# 20 -116.206453  zoneforstop_VRT_2942                       NaN       NaN
# 22 -116.205859   zoneforstop_VRT_389              Front & 9th        8.0
# 23 -116.399235  zoneforstop_VRT_2373                   CWI P&R       2.0
# 24 -116.433499  zoneforstop_VRT_3182                       NaN       NaN
# 31 -116.509559  zoneforstop_VRT_4192                       NaN       NaN
# 29 -116.573305  zoneforstop_VRT_1690                       NaN       NaN
# ..         ...                   ...                       ...       ...
# 52 -116.399235  zoneforstop_VRT_2373                   CWI P&R       2.0
# 44 -116.199019   zoneforstop_VRT_746                       NaN       NaN
# 53 -116.433499  zoneforstop_VRT_3182                       NaN       NaN
# 51 -116.204084  zoneforstop_VRT_3316              Idaho & 9th       10.0
# 56 -116.509559  zoneforstop_VRT_4192                       NaN       NaN
# 50 -116.206540  zoneforstop_VRT_3046                       NaN       NaN
# 67 -116.634915  zoneforstop_VRT_3324  Happy Day Transit Center       1.0
# 68 -116.507148   zoneforstop_VRT_351                       NaN       NaN
# 72 -116.508994  zoneforstop_VRT_3325                   CWI P&R       2.0
# 59 -116.204212  zoneforstop_VRT_2906       University & Joyce        7.0
# 60 -116.202444    zoneforstop_VRT_44                       NaN       NaN
# 62 -116.196294    zoneforstop_VRT_49                       NaN       NaN
# 61 -116.193273  zoneforstop_VRT_3212                       NaN       NaN
# 58 -116.194360   zoneforstop_VRT_744              Idaho & 1st        9.0
# 65 -116.399235  zoneforstop_VRT_2373                   CWI P&R       2.0
# 57 -116.199019   zoneforstop_VRT_746                       NaN       NaN
# 66 -116.433499  zoneforstop_VRT_3182                       NaN       NaN
# 64 -116.204084  zoneforstop_VRT_3316              Idaho & 9th       10.0
# 73 -116.509559  zoneforstop_VRT_4192                       NaN       NaN
# 63 -116.206540  zoneforstop_VRT_3046                       NaN       NaN
# 71 -116.573305  zoneforstop_VRT_1690                       NaN       NaN
# 70 -116.577638  zoneforstop_VRT_3227                       NaN       NaN
# 69 -116.599710  zoneforstop_VRT_3183                       NaN       NaN
# 79 -116.508994  zoneforstop_VRT_3325                   CWI P&R       2.0
# 80 -116.509191  zoneforstop_VRT_4191                       NaN       NaN
# 78 -116.432335  zoneforstop_VRT_3180                       NaN       NaN
# 77 -116.397947  zoneforstop_VRT_2372  Overland & Black Marlin        3.0
# 74 -116.209326  zoneforstop_VRT_2923                       NaN       NaN
# 75 -116.209731  zoneforstop_VRT_3321                       NaN       NaN
# 76 -116.204212  zoneforstop_VRT_2906       University & Joyce        7.0
#
#               Other Routes Accessible  Shelter
# 12                  42, 52        1.0      1.0
# 14                      52        1.0      0.0
# 15                      52        1.0      0.0
# 16                     NaN        0.0      0.0
# 13          42, 45, 51, 55        1.0      1.0
# 17                      42        1.0      1.0
# 18                      42        0.0      0.0
# 11                      42        NaN      NaN
# 10                      42        1.0      0.0
# 7                      NaN        1.0      0.0
# 2   10, 11, 16, 17, 43, 8x        1.0      1.0
# 1            16, 17, 2, 43        0.0      0.0
# 0                17, 2, 43        1.0      1.0
# 5                    2, 43        1.0      0.0
# 4                    2, 43        0.0      0.0
# 6                       43        1.0      0.0
# 8                    1, 43        1.0      0.0
# 9                1, 29, 43        1.0      1.0
# 3                1, 29, 43        1.0      0.0
# 25                  42, 52        1.0      1.0
# 26          42, 45, 51, 55        1.0      1.0
# 30                      42        1.0      1.0
# 21               1, 29, 43        1.0      0.0
# 19                    1, 3        1.0      1.0
# 20                 1, 3, 5        0.0      0.0
# 22                      45        0.0      0.0
# 23                      42        1.0      0.0
# 24                      42        0.0      0.0
# 31                      42        0.0      0.0
# 29                     NaN        0.0      0.0
# ..                     ...        ...      ...
# 52                      42        1.0      0.0
# 44               17, 2, 43        1.0      1.0
# 53                      42        0.0      0.0
# 51                  43, 8x        1.0      0.0
# 56                      42        0.0      0.0
# 50   11, 43, 6, 7A, 7B, 8x        1.0      0.0
# 67                  42, 52        1.0      1.0
# 68          42, 45, 51, 55        1.0      1.0
# 72                      42        1.0      1.0
# 59               1, 43, 45        1.0      1.0
# 60                  43, 45        0.0      0.0
# 62                      43        0.0      0.0
# 61                      43        0.0      1.0
# 58               17, 2, 43        1.0      1.0
# 65                      42        1.0      0.0
# 57               17, 2, 43        1.0      1.0
# 66                      42        0.0      0.0
# 64                  43, 8x        1.0      0.0
# 73                      42        0.0      0.0
# 63   11, 43, 6, 7A, 7B, 8x        1.0      0.0
# 71                     NaN        0.0      0.0
# 70                      52        1.0      0.0
# 69                      52        0.0      0.0
# 79                      42        1.0      1.0
# 80                      42        0.0      0.0
# 78                      42        NaN      NaN
# 77                      42        1.0      0.0
# 74                1, 3, 45        0.0      1.0
# 75                   1, 43        0.0      0.0
# 76               1, 43, 45        1.0      1.0
#
# [81 rows x 35 columns]

# %%
if root.route=='All':
    for i in feed.routes.route_short_name.unique():
        stopLister(i,root.outfolder)
else:
    stopLister(root.route,root.outfolder)
# Out:
# c:\users\bparker\appdata\local\conda\conda\envs\py3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
alpha=[]
for letter in range(65,65+len(test.columns)):
    alpha.append(chr(letter))
alpha
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']

# %%
list(range(math.floor(len(test.columns.get_level_values(0))/2)+1))
# Out:
# [0, 1, 2, 3, 4]

# %%
import math
math.ceil(len(test.columns.get_level_values(0))/2)
# Out:
# 4
