# %%
import pandas as pd
import numpy as np
import requests, zipfile, io, os
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize, LinearSegmentedColormap, PowerNorm
import geopandas as gpd
from gcmap import GCMapper
from shapely.geometry import Point, LineString
# %matplotlib inline

# %%
FMLM_DF=pd.DataFrame()

# %%
idaho='16'
ada_county='001'
canyon_county='027'
tracts_url=r"https://www2.census.gov/geo/tiger/TIGER2018/TRACT/tl_2018_16_tract.zip"

# %%
def readOnlineShapefile(url):
    zip_file_url=url
    r=requests.get(zip_file_url)
    z=zipfile.ZipFile(io.BytesIO(r.content))
    z.extractall("x")
    return gpd.read_file("x")
tracts=readOnlineShapefile(tracts_url)

# zip_file_url=r"https://www2.census.gov/geo/tiger/TIGER2018/COUNTY/tl_2018_us_county.zip"
# r = requests.get(zip_file_url)
# z = zipfile.ZipFile(io.BytesIO(r.content))
# z.extractall("counties")
# counties=gpd.read_file("counties")
# VRT_counties=counties.loc[(counties['STATEFP']==idaho)&((counties['COUNTYFP']==ada_county)|(counties['COUNTYFP']==canyon_county))]
# VRT_counties.head()

# %%
def getVRTServiceArea(url):
    gdf=readOnlineShapefile(url)
    gdf=gdf.loc[(gdf['COUNTYFP']==ada_county)|(gdf['COUNTYFP']==canyon_county)]
    return gdf
getVRTServiceArea(tracts_url)

# %%
zip_file_url=r"https://www2.census.gov/geo/tiger/TIGER2018/TRACT/tl_2018_16_tract.zip"
r = requests.get(zip_file_url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall("tracts")
tracts=gpd.read_file("tracts")
tracts['center']=tracts['geometry'].centroid
tracts['lon']=tracts.center.apply(lambda p: p.x)
tracts['lat']=tracts.center.apply(lambda p: p.y)
tracts=tracts.loc[(tracts['COUNTYFP']==ada_county)|(tracts['COUNTYFP']==canyon_county)]

# %%
FMLM_Folder=r"N:\Planning - New File Structure\GIS\Data\EmergingMobility\FMLM"
NiteRide_Folder=r"N:\Planning - New File Structure\GIS\Data\EmergingMobility\NiteRide"

# %%
def mobilityReader(folder,save_file=None,output_type='line'):
    df=pd.DataFrame()
    for i in os.listdir(folder):
        df=df.append(pd.read_excel(folder+"\\"+i,dtype={"Origin (Census Tract)":str,"Destination (Census Tract)":str},sheet_name='Invoice'))
        
    df_origins=df.merge(tracts,left_on="Origin (Census Tract)",right_on='GEOID')
    df_origins.drop(['center','geometry'],axis=1,inplace=True)
    df_dests=df.merge(tracts,left_on="Destination (Census Tract)",right_on="GEOID")
    df_dests.drop(['center','geometry'],axis=1,inplace=True)
    df=df_origins.join(df_dests,lsuffix='_orig',rsuffix='_dest')
    
    df['orig_coord']=[Point(xy) for xy in zip(df.lon_orig,df.lat_orig)]
    df['dest_coord']=[Point(xy)for xy in zip(df.lon_dest,df.lat_dest)]
    
    df=df[['Passenger ID_orig','Day of Travel_orig','Dispatch Method_orig','Coupon Name_orig',"Origin (Census Tract)_orig","Destination (Census Tract)_dest",'Trip Time Period_orig','Trip Length_orig','Trip Duration_orig','Trip Cost_orig','Trip Refund_orig','Trip Subsidy_orig','lon_orig','lat_orig','lon_dest','lat_dest','orig_coord','dest_coord']]
    df['line']=[LineString(xy) for xy in zip(df.orig_coord,df.dest_coord)]
    df['trips']=1
    
    gdf=gpd.GeoDataFrame(df,geometry='line',crs={'init':'epsg:4326'})
    gdf.drop(['orig_coord','dest_coord','lon_orig','lat_orig','lon_dest','lat_dest'],axis=1,inplace=True)
    gdf.rename(columns={"Origin (Census Tract)_orig":'Origin',"Destination (Census Tract)_dest":'Destination'},inplace=True)
    
    gdf2=gdf[['Origin','Destination','Trip Time Period_orig','line','trips']]
    gdf2=gdf2.dissolve(['Origin','Destination','Trip Time Period_orig'],aggfunc='sum')
    gdf2.reset_index(inplace=True)
    
    gdf_point=gdf2.loc[gdf2['Origin']==gdf2['Destination']]
    gdf_point=gdf_point.merge(tracts,left_on='Origin',right_on='GEOID')
    gdf_point=gpd.GeoDataFrame(gdf_point,geometry='center',crs={'init':'epsg:4326'})
    
    gdf_line=gdf2.loc[gdf2['Origin']!=gdf2['Destination']]
    gdf_point=gdf_point[['Origin','Destination','Trip Time Period_orig','trips','center']]
    gdf_line=gdf_line[['Origin','Destination','Trip Time Period_orig','trips','line']]
    if save_file:
        gdf_point.to_file(save_file.format("_point"),SHPT='POINT')
        gdf_line.to_file(save_file.format("_line"))
    if output_type=='line':
        return gdf_line
    if output_type=='point':
        return gdf_point
test=mobilityReader(FMLM_Folder)
test
# Out:
# c:\users\bparker\appdata\local\conda\conda\envs\py3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#          Origin  Destination Trip Time Period_orig  trips  \
# 0   16001000302  16001001202               AM PEAK      1
# 1   16001000302  16001001202                MIDDAY      6
# 2   16001000302  16001001202               PM PEAK      1
# 3   16001000303  16001001202               AM PEAK      1
# 4   16001000303  16001001202                MIDDAY      9
# 5   16001000303  16001001202               PM PEAK     16
# 6   16001000303  16001010223                MIDDAY      6
# 7   16001000303  16001010223               PM PEAK      4
# 11  16001000304  16001002310               AM PEAK      3
# 12  16001000304  16001002310                MIDDAY     10
# 13  16001000304  16001002310               PM PEAK      8
# 14  16001000400  16001001100               AM PEAK      7
# 15  16001000400  16001001100                MIDDAY      6
# 16  16001000400  16001001100               PM PEAK      2
# 17  16001000400  16001002410               AM PEAK      3
# 18  16001000400  16001002410                MIDDAY      4
# 19  16001000400  16001002410               PM PEAK      5
# 20  16001000500  16001002312               AM PEAK      1
# 21  16001000500  16001002312               PM PEAK      1
# 22  16001001100  16001002302               AM PEAK      2
# 23  16001001100  16001002302                MIDDAY     10
# 24  16001001100  16001002302               PM PEAK     13
# 25  16001001201  16001002313               PM PEAK      1
# 26  16001001201  16001002413                MIDDAY      5
# 27  16001001201  16001002413               PM PEAK      2
# 28  16001001202  16001002302               AM PEAK      4
# 29  16001001202  16001002302                MIDDAY     23
# 30  16001001202  16001002302               PM PEAK     70
# 31  16001002000  16001001202               AM PEAK     17
# 32  16001002000  16001001202                MIDDAY     36
# ..          ...          ...                   ...    ...
# 49  16001002310  16001001100               PM PEAK      6
# 50  16001002310  16001002302               AM PEAK      3
# 51  16001002310  16001002302                MIDDAY     12
# 52  16001002310  16001002302               PM PEAK      4
# 56  16001002312  16001002411                MIDDAY      1
# 57  16001002313  16001000303               AM PEAK     13
# 58  16001002313  16001000303                MIDDAY     25
# 59  16001002313  16001000303               PM PEAK      4
# 60  16001002313  16001002413               AM PEAK     17
# 61  16001002313  16001002413                MIDDAY     13
# 62  16001002313  16001002413               PM PEAK      4
# 63  16001002410  16001000400               AM PEAK     10
# 64  16001002410  16001000400                MIDDAY      8
# 65  16001002410  16001000400               PM PEAK      4
# 69  16001002411  16001001201                MIDDAY      1
# 73  16001002412  16001000400               AM PEAK      2
# 74  16001002412  16001000400                MIDDAY      4
# 75  16001002412  16001000400               PM PEAK      6
# 76  16001002412  16001001202               AM PEAK      9
# 77  16001002412  16001001202                MIDDAY     14
# 78  16001002412  16001001202               PM PEAK      7
# 79  16001002413  16001001201               AM PEAK      4
# 80  16001002413  16001001201                MIDDAY      3
# 81  16001002413  16001001201               PM PEAK      2
# 82  16001002413  16001002313               AM PEAK      4
# 83  16001002413  16001002313                MIDDAY     34
# 84  16001002413  16001002313               PM PEAK     12
